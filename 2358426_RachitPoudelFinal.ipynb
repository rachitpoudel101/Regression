# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# import pandas as pd
# file_path = '/content/drive/MyDrive/Colab Notebooks/serious-injury-outcome-indicators-2000-2020-CSV.csv'
# data = pd.read_csv(file_path)
# data.tail()

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
file_path = '/content/drive/MyDrive/apple_quality.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
data = pd.read_csv(file_path)
data.tail()
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %%
types= data.dtypes
print(types)
# Out:
# A_id           float64
# Size           float64
# Weight         float64
# Sweetness      float64
# Crunchiness    float64
# Juiciness      float64
# Ripeness       float64
# Acidity         object
# Quality         object
# dtype: object

# %%
size=data.size
print(size)
# Out:
# 36009

# %%
null_value=data.isnull().sum()
print(null_value)
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
drop = data.duplicated().sum()
print(drop)
# Out:
# 0

# %%
size=data.size
print(size)
# Out:
# 36009

# %%
for col in data:
  if data[col].dtypes == 'float64':
        min_val = data[col].min()
        max_val = data[col].max()
        data_range = max_val - min_val
        mean_val = data[col].mean()
        variance_val = data[col].var()
        std_deviation = data[col].std()

        print(f"Column: {col}")
        print(f"Min: {min_val}")
        print(f"Max: {max_val}")
        print(f"Range: {data_range}")
        print(f"Mean: {mean_val}")
        print(f"Variance: {variance_val}")
        print(f"Standard Deviation: {std_deviation}")
        print("\n")
# Out:
# Column: A_id
# Min: 0.0
# Max: 3999.0
# Range: 3999.0
# Mean: 1999.5
# Variance: 1333666.6666666667
# Standard Deviation: 1154.8448669265786
#
#
# Column: Size
# Min: -7.151703059
# Max: 6.406366899
# Range: 13.558069958
# Mean: -0.50301462982675
# Variance: 3.717410307669181
# Standard Deviation: 1.928058688854979
#
#
# Column: Weight
# Min: -7.149847675
# Max: 5.79071359
# Range: 12.940561265
# Mean: -0.9895465445945
# Variance: 2.568029371408418
# Standard Deviation: 1.6025072141517547
#
#
# Column: Sweetness
# Min: -6.894485494
# Max: 6.374915513
# Range: 13.269401007
# Mean: -0.47047851978824995
# Variance: 3.7769615947451607
# Standard Deviation: 1.943440658920452
#
#
# Column: Crunchiness
# Min: -6.055057805
# Max: 7.619851801
# Range: 13.674909606
# Mean: 0.9854779038585
# Variance: 1.9677277739685628
# Standard Deviation: 1.402757204211963
#
#
# Column: Juiciness
# Min: -5.961897048
# Max: 7.364402864
# Range: 13.326299912
# Mean: 0.5121179684932501
# ...

# %%
for col in data:
  if data[col].dtypes == 'object':
    unique_value= data[col].unique();
    mode=data[col].mode

    print(f"Column: {col}")
    print(f"Unique: {unique_value}")
    print(f"Mode: {mode}")
    print("\n")
# Out:
# Column: Acidity
# Unique: ['-0.491590483' '-0.722809367' '2.621636473' ... '-2.229719806'
#  '1.599796456' 'Created_by_Nidula_Elgiriyewithana']
# Mode: <bound method Series.mode of 0                            -0.491590483
# 1                            -0.722809367
# 2                             2.621636473
# 3                             0.790723217
# 4                             0.501984036
#                       ...
# 3996                          1.854235285
# 3997                         -1.334611391
# 3998                         -2.229719806
# 3999                          1.599796456
# 4000    Created_by_Nidula_Elgiriyewithana
# Name: Acidity, Length: 4001, dtype: object>
#
#
# Column: Quality
# Unique: ['good' 'bad' nan]
# Mode: <bound method Series.mode of 0       good
# 1       good
# 2        bad
# 3       good
# 4       good
#         ...
# 3996    good
# 3997     bad
# 3998    good
# 3999    good
# 4000     NaN
# Name: Quality, Length: 4001, dtype: object>

# %%
print(data[['Sweetness', 'Juiciness']].isnull().sum())
print(data[['Sweetness', 'Juiciness']].dtypes)
print(len(data[['Sweetness', 'Juiciness']]))
# Out:
# Sweetness    1
# Juiciness    1
# dtype: int64
# Sweetness    float64
# Juiciness    float64
# dtype: object
# 4001

# %%
data_cleaned = data.dropna(subset=['Sweetness', 'Juiciness'])

# %%
sns.pairplot(data, hue='Juiciness')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('Sweetness', axis=1), data['Juiciness'], test_size=0.2, random_state=42)
